# %%
def numOfP4(G): #This works, but it's slow as all hell
    totalP4 = set() #Set containing all unique length 4 paths
    for rootVertex in G.vertices():
        for secondVertex in G.neighbors(rootVertex):
            for thirdVertex in G.neighbors(secondVertex):
                if(thirdVertex != rootVertex):
                    for fourthVertex in G.neighbors(thirdVertex):
                        if((fourthVertex != rootVertex) and (fourthVertex != secondVertex)):
                            currentP4 = (rootVertex, secondVertex, thirdVertex, fourthVertex)
                            if(currentP4[::-1] not in totalP4):
                                totalP4.add(currentP4)
    
    print(len(totalP4)) #Prints the amount of length 4 paths

# %%
G = graphs.CompleteGraph(4)
numOfP4(G)
G.show()
# Out:
# 12
# /var/folders/12/ghp819xn1b9gs2jb75gmgk5h0000gn/T/ipykernel_3893/749750842.py:3: DeprecationWarning: parameter 'sort' will be set to False by default in the future
# See http://trac.sagemath.org/22349 for details.
#   for rootVertex in G.vertices():
# Graphics object consisting of 11 graphics primitives
